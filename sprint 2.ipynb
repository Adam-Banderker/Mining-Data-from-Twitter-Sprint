# %%
import os
import tweepy as tw
import pandas as pd


consumer_key = '14nKZvIZmVAtsPE4g3u5Zmpe4'
consumer_secret = 'GdmiaCko3tzmHboLM7B8DDvRgaSifRd6v0eoOwrL4w3fggppj5'
access_token= '1291322105364176898-vL4duCpabTBF5cUKwKz6ZQvlOmYFnc'
access_token_secret= '6NtcqT0wWh1F0NoJcRdQQFwf7oB2TScSPIWvjR1uPEW45'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
#Search Twitter for Tweets
# Define the search term and the date_since date as variables
search_words = "#blacklivesmatter"
date_since = "2019-11-16"

# %%
#i restricted the number of tweets to 100
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(100)
tweets

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(100)

# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# @GovAndyBeshear @djaycameron @DanielCameronAG @RepJohnYarmuth @RandPaul @senatemajldr It has been 148 days since Br… https://t.co/pdwQDi2Vt4
# RT @Lady44Sassy: What the actual fuck is going on here 🤯 🤯🤯
#
# #BlackLivesMatter craving attention again it seems....this is rancid &amp; disturb…
# @noregre45537216 @Nigel_Farage Can confirm you definitely won’t be missed.👍🏼 #BlackLivesMatter
# RT @MmusiMaimane: Bagaetsho. Don’t let them convince you that your tweets don’t matter. It was tweeting that started the Arab spring. It wa…
# RT @hungrybowtie: I’m here for the protest by the east precinct in Portland on Thursday, Aug 6th. I got here a bit early to scope things ou…
# RT @TVMarv: Lovely interview with a black pioneer. Cheers to #RoyHackett and @kehinde_andrews for reminding us of his fight for fairness ht…
# RT @JWSpry: NONE of these cultural “revolutionaries” have told us which system they would prefer to Western Civilisation, other than the ob…
# ...

# %%
# Collect tweets using list comprehension as it seemed to be the efficient way to collect the data
tweets = tw.Cursor(api.search,
                       q=search_words,
                       lang="en",
                       since=date_since).items(50)

# Collect a list of tweets
[tweet.text for tweet in tweets]
# Out:
# ['Black.....Lives.....WHAT??\n\nhttps://t.co/70WamTzZEb #BlackLivesMatter @ConcordDallas',
#  'RT @MrAndyNgo: “Destruction is necessary. F— peace.”\n\nFlyer given out at the Seattle “autonomous zone” encourages violent behavior. #antifa…',
#  "RT @JohnathanPerk: REALITY CHECK: nearly two-thirds of white Americans disapproved of Dr. King's civil disobedience, the lunch counter sit-…",
#  "@NewYorkStateAG @NRA Cool.  Now do #BLACKLIVESMATTER \n\nthat's an organization that is killing people and burning ci… https://t.co/75zHDDpNEW",
#  'RT @MZBJMA: #RidinWithBiden all the way to #BlackLivesMatter Plaza and the Rose Garden. \n#VoteBidenToSaveAmerica',
#  'RT @BernardKerik: Identify her, and look at her for conspiracy to obstruct justice. #AntifaTerrorists #BlackLivesMatter @FBI @TheJusticeDept',
#  'RT @BernardKerik: Identify her, and look at her for conspiracy to obstruct justice. #AntifaTerrorists #BlackLivesMatter @FBI @TheJusticeDept',
# ...

# %%
new_search = search_words + " -filter:retweets"
new_search
# Out:
# '#blacklivesmatter -filter:retweets'

# %%
tweets = tw.Cursor(api.search,
                       q=new_search,
                       lang="en",
                       since=date_since).items(5)

[tweet.text for tweet in tweets]
# Out:
# ["For clarity:\n\nIf you out there doing that good trouble and need me...\n\nI got you in every way I can.\n\nI'm working t… https://t.co/vvzwyAv3Xz",
#  'You speak like a true blairite \nA liar  a crook  a manipulative bigot imperialist anti black \nAnti muslim \nAnd only… https://t.co/kAOsALJZmC',
#  'Heaven help the black man if he struggles one more day,\nHeaven help the white man if he turns his back away.\nHeaven… https://t.co/rb4x8uPw3e',
#  '@DuquannSweeney I agree. Where are the bold ideas? Transformative? We need equity! #BlackLivesMatter #BlackPower',
#  '@MEM_PoliceDept Remember #BlackLivesMatter']

# %%
tweets = tw.Cursor(api.search, 
                           q=new_search,
                           lang="en",
                           since=date_since).items(50) 

users_locs = [[tweet.user.created_at,tweet.user.screen_name, tweet.user.statuses_count] for tweet in tweets]
users_locs
# Out:
# [[datetime.datetime(2020, 7, 24, 3, 14, 16), 'wallofvetsnh', 1401],
#  [datetime.datetime(2019, 7, 15, 8, 51, 46), 'KatlynSkett', 5110],
#  [datetime.datetime(2016, 11, 21, 9, 7, 59), 'thuli_zandile', 923],
#  [datetime.datetime(2010, 11, 21, 13, 16, 42), 'wuperkins', 128713],
#  [datetime.datetime(2010, 4, 29, 1, 38, 29), 'tammym6266', 3060],
#  [datetime.datetime(2016, 6, 9, 19, 14, 54), 'ppi_dave', 661],
#  [datetime.datetime(2013, 2, 18, 8, 17, 33), 'ReneTrevor', 18665],
#  [datetime.datetime(2010, 9, 22, 21, 59, 19), 'RTVWOW', 52320],
#  [datetime.datetime(2020, 3, 15, 14, 16, 6), 'rajni_slt', 166],
#  [datetime.datetime(2020, 7, 24, 3, 14, 16), 'wallofvetsnh', 1401],
#  [datetime.datetime(2011, 12, 9, 20, 11, 10), 'DeplorableKat', 1583],
#  [datetime.datetime(2017, 12, 4, 11, 33, 23), 'rob_bray710', 18623],
#  [datetime.datetime(2009, 10, 2, 15, 42, 51), 'kattolikamente', 83642],
#  [datetime.datetime(2019, 9, 4, 8, 16, 14), '__S_U_K_U__', 5],
# ...

# %%
#Created a Pandas Dataframe From A List of Tweet Data
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=["Datetime","User", "Tweets count"])
tweet_text
# Out:
#               Datetime             User  Tweets count
# 0  2020-07-24 03:14:16     wallofvetsnh          1401
# 1  2019-07-15 08:51:46      KatlynSkett          5110
# 2  2016-11-21 09:07:59    thuli_zandile           923
# 3  2010-11-21 13:16:42        wuperkins        128713
# 4  2010-04-29 01:38:29       tammym6266          3060
# 5  2016-06-09 19:14:54         ppi_dave           661
# 6  2013-02-18 08:17:33       ReneTrevor         18665
# 7  2010-09-22 21:59:19           RTVWOW         52320
# 8  2020-03-15 14:16:06        rajni_slt           166
# 9  2020-07-24 03:14:16     wallofvetsnh          1401
# 10 2011-12-09 20:11:10    DeplorableKat          1583
# 11 2017-12-04 11:33:23      rob_bray710         18623
# 12 2009-10-02 15:42:51   kattolikamente         83642
# 13 2019-09-04 08:16:14      __S_U_K_U__             5
# 14 2007-12-27 22:04:33    carolinediehl          5279
# 15 2017-10-17 20:06:59     GhafariaKhan           741
# ...

# %%
tweet_text.to_csv("Sprint2.csv")

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20, 10))

plt.plot(tweet_text["Tweets count"])

plt.plot(tweet_text['Tweets count'], 'go-')

plt.xlabel('User id', {'color': 'orange', 'fontsize':15})

plt.ylabel('Tweet count', {'color': 'orange', 'fontsize':15})


plt.title('TOTAL NUMBER OF TWEETS FROM PEOPLE WHO TWEETED ABOUT #BLACKLIVEMATTERS', color='purple', size=20)

plt.show()

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(tweet_text["Datetime"])

plt.plot(tweet_text['Datetime'], 'go-')

plt.xlabel('User id', {'color': 'orange', 'fontsize':15})

plt.ylabel('Year', {'color': 'orange', 'fontsize':15})


plt.title('DATE OF TWEETS FROM PEOPLE WHO USED #BLACKLIVEMATTERS', color='purple', size=20)

plt.show()
